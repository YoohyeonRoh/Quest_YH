# %% [markdown]
# <a href="https://colab.research.google.com/github/YoohyeonRoh/Quest_YH/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = open("C:\Users\uhyeo\OneDrive\바탕 화면\노유현_아이펠/06TheAvengers.txt", 'r')
data = f.read()
print(data)
f.close()
# Out:
#   File "<ipython-input-58-0e904dcc5e67>", line 1
#     f = open("C:\Users\uhyeo\OneDrive\바탕 화면\노유현_아이펠/06TheAvengers.txt", 'r')
#                                                                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import re
words = re.split(r""",|'|?| """, GOM )
print(words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-bafeb5cfce84> in <cell line: 2>()
#       1 import re
# ----> 2 words = re.split(r""",|'|?| """, GOM )
#       3 print(words)
#       4
#
# NameError: name 'GOM' is not defined

# %%
list(zip(words, words[1:]))
# Out:
# [('i', 'am'), ('am', 'hungry')]

# %%
f = open("/content/06TheAvengers.txt", 'r')
data = f.read()
print(data)
f.close()
# Out:
# The Tesseract has awakened.
# It is on a neutral world, a human world.
# They wield its power,
# but our ally knows it's working, so that they never will learn.
# He's ready to lead, and our force, our Chitauri will follow.
# The world will be his and the universe yours.
# And the humans, what can they do, but burn.
# How bad is it?
# That's the problem, sir. We don't know.
# Dr. Selvig read an energy surge from the Tesseract four hour ago.
# NASA didn't authorize Selvig to pull the test phase.
# He wasn't testing it, he wasn't even in the room. Spontaneous advancement
# It just turned itself on?
# What are the engine levels now?
# Climbing. When Selvig couldn't shut it down, we ordered the evac.
# How long to get everyone out?
# Campus should be clear in the next half hour.
# Do better.
# Sir, evacuation maybe futile.
# We should tell them to go back to sleep?
# If we can't control the Tesseract's energy,
# there may not be a minimum safe distance.
# ...

# %%
import re
from collections import Counter

data_small = data.lower()
# print(data_low)

symbols = ['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~', '\n', '\t']
for x in symbols:
 data_small = data_small.replace(x, " ")

# print(data_small)

 words = data_small.split()

# print(words)
for i in range(len(words)-1):
  bigrams = [ words[i] + " "+ words[i+1] ]
  print(bigrams)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ['ever tried']
# ['tried to']
# ['to hide']
# ['hide blueberry']
# ['blueberry yet']
# ['yet you']
# ['you re']
# ['re confused']
# ['confused about']
# ['about why']
# ['why they']
# ['they didn']
# ['didn t']
# ['t want']
# ['want you']
# ['you around']
# ['around an']
# ['an intelligence']
# ['intelligence organization']
# ['organization that']
# ['that fears']
# ['fears intelligence']
# ['intelligence historically']
# ['historically not']
# ['not possible']
# ['possible i']
# ['i think']
# ['think loki']
# ['loki s']
# ['s trying']
# ['trying to']
# ['to wind']
# ['wind us']
# ['us up']
# ['up this']
# ['this is']
# ['is a']
# ['a man']
# ['man who']
# ['who means']
# ['means to']
# ['to start']
# ['start a']
# ['a war']
# ['war and']
# ['and if']
# ['if don']
# ['don t']
# ['t stay']
# ['stay focused']
# ['focused he']
# ['he ll']
# ['ll succeed']
# ['succeed we']
# ['we have']
# ['have orders']
# ['orders we']
# ['we should']
# ...
